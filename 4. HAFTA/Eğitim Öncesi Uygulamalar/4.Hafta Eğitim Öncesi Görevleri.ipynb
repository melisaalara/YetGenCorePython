# %% [markdown]
# # Problem 1
# Sözlükleri kullanarak bir telefon rehberi yazın. Bu rehberde kullanıcıya kimin telefonunu görüntülemek istediğini sorun ve kullanıcının girdiği isme göre o kişinin telefon numarasını yazdırın. Proje sonunda elde edeceğiniz çıktı  şuna benzer olmalı:
#
#
# Lütfen numarasını öğrenmek istediğiniz kişinin adını girin: Ahmet
#
# Ahmet isimli kişinin numarası şu şekildedir: 0532 678 13 19

# %%
# 1.Problemin Çözümünü Buraya Yazınız
telefonRehberi = {
    "Melisa": "0532 555 13 19",
    "Alara": "0543 123 45 67",
    "Halit": "0568 900 65 43",
    "Akif": "0511 234 56 08",
    "Yusuf": "0533 870 54 33"
}

ad = input(" Numarasını öğrenmek istediğiniz kişinin adını giriniz: ")

if ad in telefonRehberi:
    print(f"{ad} isimli kişinin numarası şudur: {telefonRehberi[ad]}")
else:
    print(f"{ad} isimli kişinin telefon nosu kayıtlı değildir.")
# Out:
# Melisa isimli kişinin numarası şudur: 0532 555 13 19

# %% [markdown]
# # Problem 2
# Sözlükleri kullanarak bir şirket çalışanları indeksi oluşturun. Bu isim indeksinde kişilerin isimleri key, kişilerin  memleket, yaş ve görev bilgileri value olmalıdır. Burada kullanacağımız value değerleri liste olmalıdır.
#
#
# Daha sonra bir isim sorgulama ekranı gibi kullanıcıya kimin bilgilerini görüntülemek istediğini
# sorun ve sorgulanan kişinin ekranda gösterilmesini sağlayın. Proje sonunda elde edeceğiniz çıktı şu şekilde olmalı:
#
#
# Lütfen bilgilerini görüntülemek istediğiniz çalışanın ismini girin: Mehmet Yağız
#
# Mehmet Yağız= Memleket: Adana Yaş: 40 Görev: Direktör

# %%
# 2.Problemin Çözümünü Buraya Yazınız
calisanlar = {
    "Melisa Alara": ["İstanbul", 19, "Mühendis"],
    "Mehmet Yağız": ["Adana", 40, "Direktör"],
    "Çiğdem Özüberk": ["Ankara", 28, "Aşçı"],
    "Fatma Yılmaz": ["Bursa", 32, "Pazarlama Müdürü"],
    "Halit Güven": ["İzmir", 45, "Genel Müdür"]
}

ad = input("Bilgilerini görüntülemek istediğiniz çalışanın ismini girin: ")

if ad in calisanlar:
    memleket, yas, gorev = calisanlar[ad]
    print(f"{ad}= Memleket: {memleket} Yaş: {yas} Görev: {gorev}")
else:
    print(f"{ad} isimli çalışan şirket kayıtlarında bulunamadı.")
# Out:
# Çiğdem Özüberk= Memleket: Ankara Yaş: 28 Görev: Aşçı

# %% [markdown]
# # Problem 3
#
# 3 öğrenciden oluşan bir öğrenci not sözlüğü oluşturun. Bu sözlükte öğrencilerin notları value olarak bir listede toplansın.
#
# Kullanıcıya hangi öğrencinin notlarını görmek istediğini sorun. Öğrencinin notu görüntülendiğinde program sonunda şöyle bir çıktı elde etmelisiniz:
#
# ```
# Lütfen notlarını görmek istediğiniz öğrencinin adını girin: Mehmet
#
# Mehmet isimli öğrencinin      1.Sınav Notu:72
#                               2.Sınav Notu:66
#                               3.Sınav Notu:48
# Not Ortalaması: 62.0

# %%
# 3.Problemin Çözümünü Buraya Yazınız
ogrenciNotlari = {
    "Melisa": [85, 100, 92],
    "Mehmet": [72, 66, 48],
    "Halit": [90, 95, 88]
}

ad = input("Notlarını görmek istediğiniz öğrencinin adını girin: ")

if ad in ogrenciNotlari:
    notlar = ogrenciNotlari[ad]
    notOrtalama = sum(notlar) / len(notlar)
    
    print(f"{ad} isimli öğrencinin")
    print(f"                              1.Sınav Notu:{notlar[0]}")
    print(f"                              2.Sınav Notu:{notlar[1]}")
    print(f"                              3.Sınav Notu:{notlar[2]}")
    print(f"Not Ortalaması: {notOrtalama:.1f}")
else:
    print(f"{ad} isimli öğrenci kayıtlarımızda bulunamadı.")
# Out:
# Çiğdem isimli öğrenci kayıtlarımızda bulunamadı.

# %% [markdown]
# # Problem 4

# %%
# 1-  "Bmw, Mercedes, Opel, Mazda" elemanlarına sahip bir liste oluşturunuz.
arabalar = ["Bmw", "Mercedes", "Opel", "Mazda"]

# 2-  Liste Kaç elemanlıdır ?
listeUzunlugu = len(arabalar)
print(f"Liste {listeUzunlugu} elemanlıdır.")

# 3-  Listenin ilk ve son elemanı nedir ?
ilkEleman = arabalar[0]
sonEleman = arabalar[-1]
print(f"Listenin ilk elemanı: {ilkEleman}, son elemanı: {sonEleman}")

# 4-  Mazda değerini Toyota ile değiştirin.
arabalar[3] = "Toyota"
print(f"Değiştirilmiş liste: {arabalar}")

# 5-  Listenin -2 indeksindeki değer nedir ?
eksiIkiIndeks = arabalar[-2]
print(f"Listenin -2 indeksindeki değer: {eksiIkiIndeks}")

# 6-  Listenin ilk 3 elemanını alın.
ilkUcEleman = arabalar[:3]
print(f"Listenin ilk 3 elemanı: {ilkUcEleman}")

# 7-  Listenin son 2 elemanı yerine "Toyota" ve "Renault" değerlerini ekleyin.
arabalar[-2:] = ["Toyota", "Renault"]
print(f"Son 2 elemanı değiştirilmiş liste: {arabalar}")

# 8-  Listenin üzerine "Audi" ve "Nissan" değerlerini ekleyin.
arabalar.append(["Audi", "Nissan"])
print(f"Üzerine eklenmiş liste: {arabalar}")

# 9- Listenin son elemanını silin.
arabalar.pop()
print(f"Son elemanı silinmiş liste: {arabalar}")

# 10- Liste elemanlarını tersten yazdırınız.
tersListe = arabalar[::-1]
print(f"Liste elemanlarının tersten hali: {tersListe}")

# 11- Aşağıdaki verileri bir liste içinde saklayınız. 

      # studentA: Yiğit Bilgi 2010, (70,60,70)
      # studentB: Sena Turan  1999, (80,80,70)
      # studentC: Ahmet Turan 1998, (80,70,90) 
ogrenciler = [
    ["Melisa Alara", 2004, (100, 100, 100)],
    ["Halit Güven", 2009, (80, 80, 70)],
    ["Mehmet Özüberk", 1998, (80, 70, 90)]
]



# 12- Liste elemanlarını ekrana yazdırınız.
for ogrenci in ogrenciler:
    print(ogrenci)


  
names = ['Ali','Yağmur','Hakan','Deniz']
years = [1998, 2000, 1998, 1987]

# 13-  "Cenk" ismini listenin sonuna ekleyiniz.
names.append("Cenk")
print(f"'Cenk' eklenmiş liste: {names}")

# 14-  "Sena" değerini listenin başına ekleyiniz.
names.insert(0, "Sena")
print(f"'Sena' eklenmiş liste: {names}")

# 15-  "Deniz" ismini listeden siliniz.
names.remove("Deniz")
print(f"'Deniz' silinmiş liste: {names}")

# 16-  "Ali" listenin bir elemanı mıdır ?
aliVarMi = "Ali" in names
print(f"'Ali' listenin bir elemanı mı? {aliVarMi}")

# 17-  Liste elemanlarını ters çevirin.
names.reverse()
print(f"Liste elemanlarının ters çevrilmiş hali: {names}")

# 18-  Liste elemanlarını alfabetik olarak sıralayınız.
names.sort()
print(f"Alfabetik olarak sıralanmış liste: {names}")

# 19-  years listesini rakamsal büyüklüğe göre sıralayınız.
years.sort()
print(f"Rakamsal büyüklüğe göre sıralanmış years listesi: {years}")

# 20-  str = "Chevrolet,Dacia" karakter dizisini listeye çeviriniz.
strKarakter = "Chevrolet,Dacia"
strListe = strKarakter.split(',')
print(f"Karakter dizisinden oluşturulmuş liste: {strListe}")

# 21- years dizisinde kaç tane 1998 değeri vardır ?
adet1998 = years.count(1998)
print(f"years dizisinde 1998 değeri {adet1998} kere var.")

# 22- years dizisinin tüm elemanlarını siliniz.
years.clear()
print(f"years dizisinin tüm elemanları silindi: {years}")

# 23- Kullanıcıdan alacağınız 3 tane marka bilgisini bir listede saklayınız.
kullaniciMarkalar = []
for i in range(3):
    marka = input(f"{i+1}. markayı giriniz: ")
    kullaniciMarkalar.append(marka)
print(f"Kullanıcıdan alınan markalar: {kullaniciMarkalar}")
# Out:
# Liste 4 elemanlıdır.
# Listenin ilk elemanı: Bmw, son elemanı: Mazda
# Değiştirilmiş liste: ['Bmw', 'Mercedes', 'Opel', 'Toyota']
# Listenin -2 indeksindeki değer: Opel
# Listenin ilk 3 elemanı: ['Bmw', 'Mercedes', 'Opel']
# Son 2 elemanı değiştirilmiş liste: ['Bmw', 'Mercedes', 'Toyota', 'Renault']
# Üzerine eklenmiş liste: ['Bmw', 'Mercedes', 'Toyota', 'Renault', ['Audi', 'Nissan']]
# Son elemanı silinmiş liste: ['Bmw', 'Mercedes', 'Toyota', 'Renault']
# Liste elemanlarının tersten hali: ['Renault', 'Toyota', 'Mercedes', 'Bmw']
# ['Melisa Alara', 2004, (100, 100, 100)]
# ['Halit Güven', 2009, (80, 80, 70)]
# ['Mehmet Özüberk', 1998, (80, 70, 90)]
# 'Cenk' eklenmiş liste: ['Ali', 'Yağmur', 'Hakan', 'Deniz', 'Cenk']
# 'Sena' eklenmiş liste: ['Sena', 'Ali', 'Yağmur', 'Hakan', 'Deniz', 'Cenk']
# 'Deniz' silinmiş liste: ['Sena', 'Ali', 'Yağmur', 'Hakan', 'Cenk']
# 'Ali' listenin bir elemanı mı? True
# Liste elemanlarının ters çevrilmiş hali: ['Cenk', 'Hakan', 'Yağmur', 'Ali', 'Sena']
# Alfabetik olarak sıralanmış liste: ['Ali', 'Cenk', 'Hakan', 'Sena', 'Yağmur']
# Rakamsal büyüklüğe göre sıralanmış years listesi: [1987, 1998, 1998, 2000]
# Karakter dizisinden oluşturulmuş liste: ['Chevrolet', 'Dacia']
# years dizisinde 1998 değeri 2 kere var.
# years dizisinin tüm elemanları silindi: []
# Kullanıcıdan alınan markalar: ['Saka', 'Erikli', 'Beysu']
